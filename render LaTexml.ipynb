# %%
import xml.etree.ElementTree as ET
import pandas as pd
import re
import nltk
#with open('../2004_ends_with_3/math.0412433/math.0412433.xml', 'r') as fxml:
exml = ET.parse('../2004_ends_with_3/math.0402243/math.0402243.xml')

# %%
def find_theorems(exml):
    return_lst = []
    for e in exml.iter():
        if 'theorem' in e.tag:
            return_lst.append(e)
    return return_lst

def find_definitions(exml):
    return_lst = []
    for e in exml.iter():
        att_class = e.attrib.get('class', None)
        if att_class:
            if re.match(r'ltx_theorem_[definto]+$', att_class):
                return_lst.append(e)
    return return_lst
thm_lst = find_theorems(exml)
thm = thm_lst[1]

# %%
fd_lst = find_definitions(exml)
re.match(r'ltx_theorem_[definto]+$', fd_lst[2].attrib['class'])
# Out:
# <re.Match object; span=(0, 22), match='ltx_theorem_definition'>

# %%
para = list(thm)[1]
p = list(para)[0]
for t in p:
    print(list(t))
# Out:
# [<Element '{http://dlmf.nist.gov/LaTeXML}XMath' at 0x7f08c597a9a8>]
# [<Element '{http://dlmf.nist.gov/LaTeXML}XMath' at 0x7f08c5980598>]
# [<Element '{http://dlmf.nist.gov/LaTeXML}XMath' at 0x7f08c5980688>]
# [<Element '{http://dlmf.nist.gov/LaTeXML}XMath' at 0x7f08c5980c28>]
# [<Element '{http://dlmf.nist.gov/LaTeXML}XMath' at 0x7f08c5908188>]
# [<Element '{http://dlmf.nist.gov/LaTeXML}XMath' at 0x7f08c5908368>]
# []
# [<Element '{http://dlmf.nist.gov/LaTeXML}XMath' at 0x7f08c59084a8>]

# %%
Elst = ET.tostringlist(p,method='text',encoding='unicode')
' '.join([e.strip() for e in Elst])
# Out:
# 'Let    ⊆   \u2062    M  u        (  B  )    div     \u2062    M  u      (  B  )       be\nthe divisorial part of the unstable locus of   B   ; in other words,    \u2062    M  u        (  B  )    div     is the union of the irreducible components\nof    \u2062    M  u      (  B  )      having codimension one in    ~  M    . We shall say\nthat the Kirwan resolution   f   is mild if    ⊆   \u2062  f     (   \u2062    M  u        (  B  )    div    )      \u2062    M  u      (  L  )       . '

# %%
p = X.para_p(X.def_lst[0])
if p.text:
    def_str = p.text
else:
    def_str = ''
for pa in p.iter():
    if pa.text:
        def_str += pa.text
    if pa.tail:
        def_str += pa.tail
def_str
# Out:
# '\n      Une orbifolde pure est un espace analytique complexe normal \n               n’ayant que des singularités\nquotient.\n                \n            X\n              '

# %%
ET.tostring(p,method='text')
# Out:
# b'Une orbifolde pure est un espace analytique complexe normal \n              \n                X\n              \n             n&#8217;ayant que des singularit&#233;s\nquotient.\n      '

# %%
ET.tostring(pa, method='text')
# Out:
# b' est un espace analytique complexe normal \n              \n                X\n              \n             n&#8217;ayant que des singularit&#233;s\nquotient.'

# %%
list(pa)[0].tail
# Out:
# ' n’ayant que des singularités\nquotient.'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import parsing_xml as px
ns = {'latexml': 'http://dlmf.nist.gov/LaTeXML' }
X = px.DefinitionsXML('../2004_ends_with_3/math.0402243/math.0402243.xml')
X.find_definitions()
px.text1(X.para_p(X.def_lst[0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-bcf3dd0a0fd0> in <module>()
#       3 X = px.DefinitionsXML('../2004_ends_with_3/math.0402243/math.0402243.xml')
#       4 X.find_definitions()
# ----> 5 px.text1(X.para_p(X.def_lst[0]))
#
# ~/MisDocumentos/arxivBulkDownload/arxivDownload/parsing_xml.py in text1(root)
#      12     def_str = root.text
#      13     for d in list(root):
# ---> 14         def_str += d.text
#      15         def_str += d.tail
#      16     return def_str.replace('\n', ' ')
#
# TypeError: unsupported operand type(s) for +=: 'NoneType' and 'str'

# %%
Y = px.DefinitionsXML('../2004_ends_with_3/math.0412433/math.0412433.xml')
Y.get_def_text()
TT = nltk.tokenize.TweetTokenizer()
ss.issubset(set(Y.get_def_text()[0].split()))
# Out:
# True

# %%
ss = {'.',
 ';',
 'Kirwan',
 'Let',
 'We',
 'be',
 'codimension',
 'components',
 'divisorial',
 'having',
 'if',
 'in',
 'irreducible',
 'is',
 'locus',
 'mild',
 'of',
 'one',
 'other',
 'part',
 'resolution',
 'say',
 'shall',
 'that',
 'the',
 'union',
 'unstable',
 'words,'}

# %%
Y.get_def_text()[0].split()
# Out:
# ['Let',
#  'be',
#  'the',
#  'divisorial',
#  'part',
#  'of',
#  'the',
#  'unstable',
#  'locus',
#  'of',
#  ';',
#  'in',
#  'other',
#  'words,',
#  'is',
#  'the',
#  'union',
#  'of',
#  'the',
#  'irreducible',
#  'components',
#  'of',
#  'having',
#  'codimension',
#  'one',
#  'in',
#  '.',
#  'We',
#  'shall',
#  'say',
#  'that',
#  'the',
#  'Kirwan',
#  'resolution',
#  'is',
#  'mild',
#  'if',
#  '.']

# %%
E = exml.getroot().findall('{http://dlmf.nist.gov/LaTeXML}section')[0]
for E
# Out:
# [<Element '{http://dlmf.nist.gov/LaTeXML}section' at 0x7f08c61888b8>,
#  <Element '{http://dlmf.nist.gov/LaTeXML}section' at 0x7f08c5ae1458>,
#  <Element '{http://dlmf.nist.gov/LaTeXML}section' at 0x7f08c59632c8>,
#  <Element '{http://dlmf.nist.gov/LaTeXML}section' at 0x7f08c5631138>]

# %%
for e in exml.getroot():
    print(e.tag)
# Out:
# {http://dlmf.nist.gov/LaTeXML}resource
# {http://dlmf.nist.gov/LaTeXML}resource
# {http://dlmf.nist.gov/LaTeXML}title
# {http://dlmf.nist.gov/LaTeXML}creator
# {http://dlmf.nist.gov/LaTeXML}date
# {http://dlmf.nist.gov/LaTeXML}section
# {http://dlmf.nist.gov/LaTeXML}section
# {http://dlmf.nist.gov/LaTeXML}section
# {http://dlmf.nist.gov/LaTeXML}section
# {http://dlmf.nist.gov/LaTeXML}bibliography

# %%
for e in exml.iter():
    print(e.tag)
# Out:
# {http://dlmf.nist.gov/LaTeXML}document
# {http://dlmf.nist.gov/LaTeXML}resource
# {http://dlmf.nist.gov/LaTeXML}resource
# {http://dlmf.nist.gov/LaTeXML}title
# {http://dlmf.nist.gov/LaTeXML}creator
# {http://dlmf.nist.gov/LaTeXML}personname
# {http://dlmf.nist.gov/LaTeXML}note
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}date
# {http://dlmf.nist.gov/LaTeXML}section
# {http://dlmf.nist.gov/LaTeXML}title
# {http://dlmf.nist.gov/LaTeXML}tag
# {http://dlmf.nist.gov/LaTeXML}para
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}para
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}equation
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}para
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}equation
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}cite
# {http://dlmf.nist.gov/LaTeXML}bibref
# {http://dlmf.nist.gov/LaTeXML}cite
# {http://dlmf.nist.gov/LaTeXML}bibref
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}cite
# {http://dlmf.nist.gov/LaTeXML}bibref
# {http://dlmf.nist.gov/LaTeXML}cite
# {http://dlmf.nist.gov/LaTeXML}bibref
# {http://dlmf.nist.gov/LaTeXML}cite
# {http://dlmf.nist.gov/LaTeXML}bibref
# {http://dlmf.nist.gov/LaTeXML}cite
# {http://dlmf.nist.gov/LaTeXML}bibref
# {http://dlmf.nist.gov/LaTeXML}para
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}cite
# {http://dlmf.nist.gov/LaTeXML}bibref
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}ref
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}para
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}cite
# {http://dlmf.nist.gov/LaTeXML}bibref
# {http://dlmf.nist.gov/LaTeXML}cite
# {http://dlmf.nist.gov/LaTeXML}bibref
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}equation
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}para
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}para
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}para
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}para
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}theorem
# {http://dlmf.nist.gov/LaTeXML}title
# {http://dlmf.nist.gov/LaTeXML}tag
# {http://dlmf.nist.gov/LaTeXML}para
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}description
# {http://dlmf.nist.gov/LaTeXML}item
# {http://dlmf.nist.gov/LaTeXML}tag
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}para
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}item
# {http://dlmf.nist.gov/LaTeXML}tag
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}para
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}equation
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# ...
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}cite
# {http://dlmf.nist.gov/LaTeXML}bibref
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}para
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}ref
# {http://dlmf.nist.gov/LaTeXML}equation
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}equation
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMDual
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMRef
# {http://dlmf.nist.gov/LaTeXML}XMWrap
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}p
# {http://dlmf.nist.gov/LaTeXML}bibliography
# {http://dlmf.nist.gov/LaTeXML}title
# {http://dlmf.nist.gov/LaTeXML}biblist
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}Math
# {http://dlmf.nist.gov/LaTeXML}XMath
# {http://dlmf.nist.gov/LaTeXML}XMApp
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}XMTok
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}bibitem
# {http://dlmf.nist.gov/LaTeXML}bibtag
# {http://dlmf.nist.gov/LaTeXML}bibblock
# {http://dlmf.nist.gov/LaTeXML}text
# {http://dlmf.nist.gov/LaTeXML}text
